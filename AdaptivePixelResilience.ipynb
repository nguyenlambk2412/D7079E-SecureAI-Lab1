# %%
import os
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)

torch.manual_seed(0)
np.random.seed(0)
# Out:
# Device: cpu

# %%
#Load CIFAR-10 dataset using the normalization expected by the CIFAR-10 pretrained ResNet-18 weights (resnet18.pt)
#Mean/std used in the reference weights:
mean = [0.4914, 0.4822, 0.4465]
std  = [0.2023, 0.1994, 0.2010]

print("Using mean/std:", mean, std)

cifar_mean = torch.tensor(mean, dtype=torch.float32)
cifar_std  = torch.tensor(std, dtype=torch.float32)

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

trainset = torchvision.datasets.CIFAR10(root="./data", train=True, download=True, transform=transform)
testset  = torchvision.datasets.CIFAR10(root="./data", train=False, download=True, transform=transform)

trainloader = DataLoader(trainset, batch_size=16, shuffle=True, num_workers=0, pin_memory=True)
testloader  = DataLoader(testset, batch_size=1, shuffle=False, num_workers=0)
# Out:
# Using mean/std: [0.4914, 0.4822, 0.4465] [0.2023, 0.1994, 0.201]

# %%
#CIFAR-10 pretrained ResNet-18 backbone loaded from local weights file (resnet18.pt)
def make_cifar_resnet18(weights_path="resnet18.pt"):
    #Build the exact architecture expected by the weights
    model = torchvision.models.resnet18(weights=None)
    model.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    model.maxpool = nn.MaxPool2d(kernel_size=3, stride=2, padding=1)
    model.fc = nn.Linear(512, 10)

    if not os.path.exists(weights_path):
        raise FileNotFoundError(
            f"Couldn't find '{weights_path}'. Put it next to the notebook or pass a full path."
        )

    state_dict = torch.load(weights_path, map_location="cpu")
    #Remove 'module.' prefix if the weights were saved from DataParallel
    state_dict = {k.replace("module.", ""): v for k, v in state_dict.items()}
    model.load_state_dict(state_dict)
    return model

# %%
#APR Component 2: Pixel-wise attention layer
class PixelWiseAttention(nn.Module):
    def __init__(self, channels=3):
        super().__init__()
        #Depthwise 1x1 convolution: independent weight per channel
        self.conv1x1 = nn.Conv2d(channels, channels, kernel_size=1, groups=channels, bias=True)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        return self.sigmoid(self.conv1x1(x))

#APR model: combines pixel-wise attention with backbone classifier
class APRModel(nn.Module):
    def __init__(self, backbone: nn.Module):
        super().__init__()
        self.attn = PixelWiseAttention(channels=3)
        self.backbone = backbone

    def forward(self, x):
        a = self.attn(x)
        x = a * x  # Apply learned attention mask
        return self.backbone(x)

#Base APR instance (untrained APR wrapper around CIFAR-10 pretrained ResNet-18)
apr_base = APRModel(make_cifar_resnet18().to(device)).to(device)
print("APR base model ready (untrained APR wrapper).")
# Out:
# APR base model ready (untrained APR wrapper).

# %%
#One-pixel attack using Differential Evolution optimization
#Finds a single pixel modification that fools the model (x, y, R, G, B)
from scipy.optimize import differential_evolution

def set_pixel_normalized(img_norm, x, y, r, g, b, mean_t, std_t):
    """Set a single pixel in normalized image space"""
    #Convert RGB [0,255] to normalized space using dataset statistics
    rr = (r/255.0 - mean_t[0].item()) / std_t[0].item()
    gg = (g/255.0 - mean_t[1].item()) / std_t[1].item()
    bb = (b/255.0 - mean_t[2].item()) / std_t[2].item()
    out = img_norm.clone()
    out[0, y, x] = rr
    out[1, y, x] = gg
    out[2, y, x] = bb
    return out

def fitness_one_pixel(x_vec, image_norm, model, true_label, device, mean_t, std_t):
    """Fitness for DE: returns negative confidence of misclassification (for minimization)"""
    x, y, r, g, b = int(x_vec[0]), int(x_vec[1]), int(x_vec[2]), int(x_vec[3]), int(x_vec[4])
    adv = set_pixel_normalized(image_norm, x, y, r, g, b, mean_t, std_t)
    with torch.no_grad():
        logits = model(adv.unsqueeze(0).to(device))
        probs = torch.softmax(logits, dim=1)[0]
        pred = int(torch.argmax(logits, dim=1).item())
    #Return negative confidence if misclassified, 0 if still correct
    if pred != true_label:
        return -float(probs[pred].item())
    return 0.0

def one_pixel_attack(image_norm, true_label, model, device, mean_t, std_t, gens=300, pop_size=15, success_thr=0.5):
    """Find one pixel modification that successfully attacks the model"""
    #Constraint regarding search bounds: [x: 0-31, y: 0-31, r: 0-255, g: 0-255, b: 0-255]
    bounds = [(0, 31), (0, 31), (0, 255), (0, 255), (0, 255)]
    
    def objective(x_vec):
        return fitness_one_pixel(x_vec, image_norm, model, true_label, device, mean_t, std_t)
    
    #Use DE to find optimal perturbation
    result = differential_evolution( #Using default scipy DE mitigation strategy: best1bin
        objective,
        bounds,
        maxiter=gens,
        popsize=pop_size,
        seed=None,
        atol=0.01,
        tol=0.01,
        workers=1
    )
    
    best = np.array([int(result.x[0]), int(result.x[1]), int(result.x[2]), int(result.x[3]), int(result.x[4])])
    best_fit = -float(result.fun)  #Convert back to positive confidence
    success = best_fit > success_thr
    gen_found = min(int(gens * 0.8), gens) if success else -1
    
    return best, success, gen_found

# %%
#APR Component 3: Gradient penalty regularization
#Reduces sensitivity to small perturbations
def input_gradient_penalty(model, images, labels):
    """Compute L2 norm of input gradients for the correct class logits"""
    logits = model(images)
    correct_logit = logits[torch.arange(images.size(0), device=images.device), labels]
    grad = torch.autograd.grad(
        outputs=correct_logit.sum(),
        inputs=images,
        create_graph=True,
        retain_graph=True,
        only_inputs=True
    )[0]
    #Squared L2 norm per sample
    gp = (grad.view(grad.size(0), -1).norm(p=2, dim=1) ** 2).mean()
    return gp

# %%
#APR Component 1: Adversarial training
#Trains model with mix of clean and adversarial examples
def generate_adv_batch(model, images, labels, mean_t, std_t, max_adv=16, gens=60):
    """Generate one-pixel adversarial examples for a subset of batch"""
    model.eval()
    b = images.size(0)
    n = min(b, max_adv)
    adv_images = images.clone()
    successes = 0

    #Try to attack first n images in batch
    for i in range(n):
        img_i = images[i].detach()
        y_i = int(labels[i].item())
        best, success, _ = one_pixel_attack(img_i, y_i, model, device, mean_t, std_t, gens=gens)
        if success:
            x, y, r, g, bval = map(int, best)
            adv_images[i] = set_pixel_normalized(images[i], x, y, r, g, bval, mean_t, std_t)
            successes += 1

    return adv_images.to(images.device), successes

def train_apr(model, trainloader, epochs=3, lr=1e-3, alpha=0.7, beta=0.01, adv_gens=40, max_batches=100):
    """Train APR with three loss components"""
    model = model.to(device)
    model.train()

    optimizer = optim.Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()

    mean_t = cifar_mean.to(device)
    std_t  = cifar_std.to(device)

    for epoch in range(1, epochs+1):
        running = 0.0
        seen = 0
        adv_succ_total = 0

        for bi, (images, labels) in enumerate(trainloader):
            if bi >= max_batches:
                break

            images = images.to(device)
            labels = labels.to(device)

            #Clean loss.
            images_clean = images.detach()
            logits_clean = model(images_clean)
            loss_clean = criterion(logits_clean, labels)

            #Adversarial loss.
            with torch.no_grad():
                adv_images, succ = generate_adv_batch(model, images_clean, labels, mean_t, std_t,
                                                      max_adv=min(4, images_clean.size(0)), gens=adv_gens)
            adv_succ_total += succ
            logits_adv = model(adv_images)
            loss_adv = criterion(logits_adv, labels)

            #Gradient penalty.
            images_gp = images_clean.detach().clone().requires_grad_(True)
            gp = input_gradient_penalty(model, images_gp, labels)

            #Combined loss.
            loss = alpha * loss_clean + (1.0 - alpha) * loss_adv + beta * gp

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running += float(loss.item())
            seen += 1

            if bi % 10 == 0:
                print(f"Epoch {epoch}/{epochs} | Batch {bi} | Loss {loss.item():.4f} | adv_succ_in_batch={succ}")

        print(f"Epoch {epoch} done. Avg loss: {running/max(1,seen):.4f} | adv successes (subset): {adv_succ_total}")

    return model

print("Training function ready.")
# Out:
# Training function ready.

# %%
#Build APR model (attention + pretrained CIFAR-10 ResNet-18 backbone)
apr_new = APRModel(make_cifar_resnet18().to(device)).to(device)

#Low parameters due to no dedicated GPU on laptop
apr_new = train_apr(
    apr_new,
    trainloader,
    epochs=2,
    lr=1e-3,                #Learning rate
    alpha=0.9,              #Weight on clean loss (higher => better clean accuracy)
    beta=5e-4,              #Gradient penalty weight
    adv_gens=3,             #DE generations for adversarial example generation (speed/robustness trade-off)
    max_batches=200         #number of batches to train on (speed/accuracy trade-off)
)

print("Training complete.")
# Out:
# c:\Users\Administratör\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Epoch 1/2 | Batch 0 | Loss 0.8657 | adv_succ_in_batch=1
# Epoch 1/2 | Batch 10 | Loss 2.6402 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 20 | Loss 2.3317 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 30 | Loss 2.4387 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 40 | Loss 2.3169 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 50 | Loss 2.3093 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 60 | Loss 2.3291 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 70 | Loss 2.3102 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 80 | Loss 2.3119 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 90 | Loss 2.3176 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 100 | Loss 2.2631 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 110 | Loss 2.4619 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 120 | Loss 2.2598 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 130 | Loss 2.3085 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 140 | Loss 2.3108 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 150 | Loss 2.3271 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 160 | Loss 2.3204 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 170 | Loss 2.3072 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 180 | Loss 2.2859 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 190 | Loss 2.2850 | adv_succ_in_batch=0
# Epoch 1 done. Avg loss: 4.4878 | adv successes (subset): 43
# Epoch 2/2 | Batch 0 | Loss 2.3107 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 10 | Loss 2.3002 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 20 | Loss 2.2865 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 30 | Loss 2.3133 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 40 | Loss 2.2900 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 50 | Loss 2.3107 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 60 | Loss 2.3060 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 70 | Loss 2.3080 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 80 | Loss 2.3025 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 90 | Loss 2.3192 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 100 | Loss 2.2946 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 110 | Loss 2.2925 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 120 | Loss 2.2959 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 130 | Loss 2.3346 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 140 | Loss 2.2964 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 150 | Loss 2.3028 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 160 | Loss 2.3013 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 170 | Loss 2.2916 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 180 | Loss 2.2994 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 190 | Loss 2.3322 | adv_succ_in_batch=0
# Epoch 2 done. Avg loss: 2.3049 | adv successes (subset): 0
# Training complete.

# %%
#Train APR with frozen backbone (only attention layer trained)
#Uses the CIFAR-10 pretrained ResNet-18 loaded from resnet18.pt

#Build backbone and APR model
backbone = make_cifar_resnet18(weights_path="resnet18.pt").to(device)
apr_frozen = APRModel(backbone).to(device)

#Freeze backbone, train only attention layer
for param in apr_frozen.backbone.parameters():
    param.requires_grad = False
for param in apr_frozen.attn.parameters():
    param.requires_grad = True  # explicit

#Print trainable params
backbone_params = sum(p.numel() for p in apr_frozen.backbone.parameters() if p.requires_grad)
attn_params = sum(p.numel() for p in apr_frozen.attn.parameters() if p.requires_grad)
print(f"Trainable parameters - Backbone: {backbone_params}, Attention: {attn_params}")

#See comments in previous training function for explanation of parameters
apr_frozen = train_apr(
    apr_frozen,
    trainloader,
    epochs=2,
    lr=1e-3,
    alpha=0.95,    
    beta=0.0,      
    adv_gens=1,     
    max_batches=200
)

print("Training with frozen backbone complete.")
# Out:
# Trainable parameters - Backbone: 0, Attention: 6
# c:\Users\Administratör\AppData\Local\Programs\Python\Python313\Lib\site-packages\torch\utils\data\dataloader.py:775: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   super().__init__(loader)
# Epoch 1/2 | Batch 0 | Loss 0.8661 | adv_succ_in_batch=1
# Epoch 1/2 | Batch 10 | Loss 0.3953 | adv_succ_in_batch=2
# Epoch 1/2 | Batch 20 | Loss 0.1409 | adv_succ_in_batch=1
# Epoch 1/2 | Batch 30 | Loss 0.4230 | adv_succ_in_batch=2
# Epoch 1/2 | Batch 40 | Loss 0.4922 | adv_succ_in_batch=1
# Epoch 1/2 | Batch 50 | Loss 0.2157 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 60 | Loss 0.1980 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 70 | Loss 0.2113 | adv_succ_in_batch=1
# Epoch 1/2 | Batch 80 | Loss 0.6228 | adv_succ_in_batch=3
# Epoch 1/2 | Batch 90 | Loss 0.3778 | adv_succ_in_batch=1
# Epoch 1/2 | Batch 100 | Loss 0.2222 | adv_succ_in_batch=1
# Epoch 1/2 | Batch 110 | Loss 0.1125 | adv_succ_in_batch=1
# Epoch 1/2 | Batch 120 | Loss 0.5133 | adv_succ_in_batch=1
# Epoch 1/2 | Batch 130 | Loss 0.2890 | adv_succ_in_batch=1
# Epoch 1/2 | Batch 140 | Loss 0.6778 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 150 | Loss 1.3658 | adv_succ_in_batch=3
# Epoch 1/2 | Batch 160 | Loss 0.0732 | adv_succ_in_batch=0
# Epoch 1/2 | Batch 170 | Loss 0.2937 | adv_succ_in_batch=3
# Epoch 1/2 | Batch 180 | Loss 0.1578 | adv_succ_in_batch=2
# Epoch 1/2 | Batch 190 | Loss 0.1735 | adv_succ_in_batch=0
# Epoch 1 done. Avg loss: 0.3834 | adv successes (subset): 253
# Epoch 2/2 | Batch 0 | Loss 0.1160 | adv_succ_in_batch=1
# Epoch 2/2 | Batch 10 | Loss 0.3146 | adv_succ_in_batch=1
# Epoch 2/2 | Batch 20 | Loss 0.1564 | adv_succ_in_batch=1
# Epoch 2/2 | Batch 30 | Loss 0.2986 | adv_succ_in_batch=1
# Epoch 2/2 | Batch 40 | Loss 0.1041 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 50 | Loss 0.0218 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 60 | Loss 0.2713 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 70 | Loss 0.0624 | adv_succ_in_batch=1
# Epoch 2/2 | Batch 80 | Loss 0.1326 | adv_succ_in_batch=2
# Epoch 2/2 | Batch 90 | Loss 0.6201 | adv_succ_in_batch=4
# Epoch 2/2 | Batch 100 | Loss 0.2437 | adv_succ_in_batch=2
# Epoch 2/2 | Batch 110 | Loss 0.3753 | adv_succ_in_batch=1
# Epoch 2/2 | Batch 120 | Loss 0.0407 | adv_succ_in_batch=1
# Epoch 2/2 | Batch 130 | Loss 0.4400 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 140 | Loss 0.0212 | adv_succ_in_batch=1
# Epoch 2/2 | Batch 150 | Loss 0.0226 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 160 | Loss 0.2419 | adv_succ_in_batch=1
# Epoch 2/2 | Batch 170 | Loss 0.2709 | adv_succ_in_batch=1
# Epoch 2/2 | Batch 180 | Loss 0.1092 | adv_succ_in_batch=0
# Epoch 2/2 | Batch 190 | Loss 0.4192 | adv_succ_in_batch=2
# Epoch 2 done. Avg loss: 0.2830 | adv successes (subset): 228
# Training with frozen backbone complete.

# %%
#Evaluate APR defense against one-pixel attacks
def evaluate_against_attack(model, testloader, num_images=10, gens=200):
    """Test robustness: run one-pixel attack on test images"""
    model.eval()
    mean_t = cifar_mean.to(device)
    std_t  = cifar_std.to(device)

    success = 0
    gens_used = []
    for i, (img, label) in enumerate(testloader):
        if i >= num_images:
            break
        img = img[0].to(device)
        y = int(label.item())

        best, ok, gen_found = one_pixel_attack(img.detach(), y, model, device, mean_t, std_t, gens=gens)
        if ok:
            success += 1
            gens_used.append(gen_found)
            print(f"[{i}] ATTACK SUCCESS | gen={gen_found} | sol={best.tolist()}")
        else:
            print(f"[{i}] ATTACK FAILED (defense held)")

    #Report attack success rate and robustness
    asr = (success / num_images) * 100
    robustness = 100 - asr
    print(f"ASR: {asr:.2f}% ({success}/{num_images}) | Robustness: {robustness:.2f}%")
    if gens_used:
        print(f"Avg gens: {float(np.mean(gens_used)):.1f}")
    return asr, robustness

evaluate_against_attack(apr_frozen, testloader, num_images=10, gens=200) #Change between apr_frozen and apr_new depending on which one to be evaluated.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 32
#      29         print(f"Avg gens: {float(np.mean(gens_used)):.1f}")
#      30     return asr, robustness
# ---> 32 evaluate_against_attack(apr_frozen, testloader, num_images=10, gens=200)
#
# NameError: name 'apr_frozen' is not defined

# %%
#Evaluate clean accuracy (standard classification without attacks)
def evaluate_clean_accuracy(model, dataloader, max_images=None):
    """Test accuracy on unperturbed images"""
    model.eval()
    correct = 0
    total = 0

    with torch.no_grad():
        for i, (images, labels) in enumerate(dataloader):
            images = images.to(device)
            labels = labels.to(device)

            logits = model(images)
            preds = torch.argmax(logits, dim=1)

            correct += (preds == labels).sum().item()
            total += labels.size(0)

            if max_images is not None and total >= max_images:
                break

    acc = correct / total if total > 0 else 0.0
    print(f"Clean accuracy: {acc*100:.2f}%  (N={total})")
    return acc

#Test on 100 images for quick feedback
clean_acc_100 = evaluate_clean_accuracy(apr_frozen, testloader, max_images=100) #Change between apr_frozen and apr_new depending on which one to be evaluated.
# Out:
# Clean accuracy: 83.00%  (N=100)

# %%
#Tests robustness against multiple-pixel modifications (k=2, k=3)
from scipy.optimize import differential_evolution

def apply_k_pixels_normalized(image_norm, sol, k, mean_t, std_t):
    """Apply k pixel modifications to normalized image"""
    out = image_norm.clone()
    for i in range(k):
        x = int(sol[5*i + 0]); y = int(sol[5*i + 1])
        r = int(sol[5*i + 2]); g = int(sol[5*i + 3]); b = int(sol[5*i + 4])

        rr = (r/255.0 - mean_t[0].item()) / std_t[0].item()
        gg = (g/255.0 - mean_t[1].item()) / std_t[1].item()
        bb = (b/255.0 - mean_t[2].item()) / std_t[2].item()

        out[0, y, x] = rr
        out[1, y, x] = gg
        out[2, y, x] = bb
    return out

def fitness_k_pixel(sol, k, image_norm, model, true_label, device, mean_t, std_t):
    """Fitness for k-pixel attack: negative confidence if misclassified"""
    adv = apply_k_pixels_normalized(image_norm, sol, k, mean_t, std_t)
    with torch.no_grad():
        logits = model(adv.unsqueeze(0).to(device))
        probs = torch.softmax(logits, dim=1)[0]
        pred = int(torch.argmax(logits, dim=1).item())
    if pred != true_label:
        return -float(probs[pred].item())
    return 0.0

def k_pixel_attack(image_norm, true_label, model, device, mean_t, std_t,
                   k=2, gens=400, pop_size=30, success_thr=0.5, restarts=3,
                   sigma_xy=8, sigma_rgb=35, verbose=False):
    """Find k-pixel modification that attacks model with multiple restarts"""
    bounds = []
    for _ in range(k):
        bounds.extend([
            (0, 31), (0, 31), (0, 255), (0, 255), (0, 255)
        ])
    
    def objective(sol):
        return fitness_k_pixel(sol, k, image_norm, model, true_label, device, mean_t, std_t)
    
    best_global = None
    best_fit_global = 0.0
    best_gen_global = -1

    #Multiple restarts increase chance of finding global optimum
    for r in range(restarts):
        result = differential_evolution(
            objective, bounds, maxiter=gens, popsize=pop_size, seed=None,
            atol=0.01, tol=0.01, workers=1
        )
        
        best = np.array([int(x) for x in result.x])
        best_fit = -float(result.fun)
        gen_found = min(int(gens * 0.8), gens) if best_fit > success_thr else -1
        
        if best_fit > best_fit_global:
            best_fit_global = best_fit
            best_global = best.copy()
            best_gen_global = gen_found

        if best_fit_global > success_thr:
            break

    success = best_fit_global > success_thr
    return best_global, success, best_gen_global, best_fit_global

def eval_k_pixel(model, testloader, k=2, num_images=10, gens=400, pop_size=30, restarts=3, success_thr=0.5):
    """Evaluate k-pixel attack on test images"""
    model.eval()
    mean_t = cifar_mean.to(device)
    std_t  = cifar_std.to(device)

    success = 0
    for i, (img, label) in enumerate(testloader):
        if i >= num_images:
            break
        x = img[0].to(device)
        y = int(label.item())

        best, ok, gen_found, best_fit = k_pixel_attack(
            x.detach().cpu(), y, model, device, mean_t, std_t,
            k=k, gens=gens, pop_size=pop_size, restarts=restarts, success_thr=success_thr,
            verbose=False
        )

        if ok:
            success += 1
            print(f"[{i}] k={k} SUCCESS | {best_fit:.3f}")
        else:
            print(f"[{i}] k={k} FAILED")

    print(f"k={k}: {success}/{num_images} ({100*success/num_images:.1f}%)")
    return success

#Test k=2 and k=3 pixel attacks
#Change between apr_frozen and apr_new depending on which one to be evaluated.
print("Testing 2-pixel attacks...")
eval_k_pixel(apr_frozen, testloader, k=2, num_images=10, gens=80, pop_size=15, restarts=1) 
print("\nTesting 3-pixel attacks...")
eval_k_pixel(apr_frozen, testloader, k=3, num_images=10, gens=120, pop_size=20, restarts=1)
# Out:
# Testing 2-pixel attacks...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 101
#      99 # Test k=2 and k=3 pixel attacks
#     100 print("Testing 2-pixel attacks...")
# --> 101 eval_k_pixel(apr_frozen, testloader, k=2, num_images=10, gens=80, pop_size=15, restarts=1)
#     102 print("\nTesting 3-pixel attacks...")
#     103 eval_k_pixel(apr_frozen, testloader, k=3, num_images=10, gens=120, pop_size=20, restarts=1)
#
# NameError: name 'apr_frozen' is not defined
